# %%
import statistics as stat 
NF = [4.475, 5.55, 6.6, 6.175, 6.64999999999999]

# %%
mediana = stat.median(NF)

# %%
import numpy as np
import random as rd
from matplotlib import pyplot as plt

data = NF
bins = np.array([2.5, 3.685, 4.37, 5.055, 5.74, 6.425, 7.11, 7.795, 8.48, 9.165, 9.8])

plt.xlim([min(data) - 1.0, max(data) + 0.5])
plt.hist(data, bins=bins, alpha=0.5)
plt.ylabel('Quantidade')
plt.show()
